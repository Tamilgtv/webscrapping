# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome(executable_path='D:/Tamil/chrome driver/chromedriver.exe')

# %%
driver.get('https://www.remax.com/real-estate-agents?count=100&sortBy=firstName')

# %%
driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div/form/div/div[2]/div[3]/div/div[4]').click()

# %%
driver.get('https://www.remax.com/real-estate-agents?count=100&sortBy=firstName')
agent_links = []
for page in range(0,2):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    for agent_det in soup.find_all('a',{'data-test':'agent-card-name'}):
        agent_links.append('https://www.remax.com'+agent_det['href'])
        
    driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div/form/div/div[2]/div[3]/div/div[4]').click()
    time.sleep(10)

# %%
while True:

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup.find_all('a',{'data-test':'agent-card-name'})
# Out:
# [<a class="name" data-test="agent-card-name" data-v-28548433="" href="/real-estate-agents/elle-tucker-humble-tx/102194775" target="">
#          "Elle"  Tucker
#        </a>,
#  <a class="name" data-test="agent-card-name" data-v-28548433="" href="/real-estate-agents/jj-jennie-mistretta-manalapan-nj/100018188" target="">
#          "JJ" Jennie  Mistretta
#        </a>,
#  <a class="name" data-test="agent-card-name" data-v-28548433="" href="/real-estate-agents/mike-david-metter-fallbrook-ca/102112372" target="">
#          "Mike" David  Metter
#        </a>,
#  <a class="name" data-test="agent-card-name" data-v-28548433="" href="/real-estate-agents/charley-schmitt-crs-cips-sacramento-ca/100046543" target="">
#          'Charley'  Schmitt, CRS, CIPS
#        </a>,
#  <a class="name" data-test="agent-card-name" data-v-28548433="" href="/real-estate-agents/ted-tetsuro-motoyama-daly-city-ca/101937392" target="">
#          'Ted' Tetsuro  Motoyama
#        </a>,
# ...

# %%
len(soup.find_all('a',{'data-test':'agent-card-name'}))
# Out:
# 100

# %%
driver.find_element_by_xpath('//div[@class="pagination-input mx-2 dinput dinput--remax"]/input').send_keys(5)

# %%
driver.get('https://www.remax.com/real-estate-agents?count=100&sortBy=firstName')
agent_links = []
for page in range(1,5):
    if page != 1:
        driver.find_element_by_xpath('//div[@class="pagination-input mx-2 dinput dinput--remax"]/input').clear()
        driver.find_element_by_xpath('//div[@class="pagination-input mx-2 dinput dinput--remax"]/input').send_keys(page)
        time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    for agent_det in soup.find_all('a',{'data-test':'agent-card-name'}):
        agent_links.append('https://www.remax.com'+agent_det['href'])
        
    #driver.find_element_by_xpath('//*[@id="__layout"]/div/main/div/form/div/div[2]/div[3]/div/div[4]').click()
#     driver.find_element_by_xpath('//div[@class="pagination-input mx-2 dinput dinput--remax"]/input').clear()
#     driver.find_element_by_xpath('//div[@class="pagination-input mx-2 dinput dinput--remax"]/input').send_keys(page)

# %%
len(set(agent_links))
# Out:
# 397
