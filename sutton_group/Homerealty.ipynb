# %%
from selenium import webdriver
import pandas as pd
import time

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
driver = webdriver.Chrome(executable_path='D:/Tamil/chrome driver/chromedriver.exe')

# %%
driver.get('https://www.homelife.ca/office_agents/8008')

# %%
soup  = BeautifulSoup(driver.page_source, 'html.parser')

# %%
soup.find('td',{'class':'agent-short-cell-right'}).find('div').span.b.text.strip()
# Out:
# 'Barbara T.   Poplawski'

# %%
soup.find('td',{'class':'agent-short-cell-right'}).find('div').find_all('span')[1].text.replace(',','').strip()
# Out:
# 'Sales Representative'

# %%
soup.find('td',{'class':'agent-short-cell-right'}).find_all('div')[1].text
# Out:
# 'HomeLife Regional Realty Ltd., Brokerage*'

# %%
soup.find('td',{'class':'agent-short-cell-right'}).find_all('div')[2].text
# Out:
# 'Office: 416-535-3107 '

# %%
soup.find('td',{'class':'agent-short-cell-right'}).find_all('div')[3].text
# Out:
# 'Fax: 416-535-5372 '

# %%
'https://www.homelife.ca'+soup.find('td',{'class':'agent-short-cell-right'}).find_all('div')[5].find('span').find('a')['href']
# Out:
# 'https://www.homelife.ca/node/9469'

# %%
df = pd.DataFrame([])
z = 0
for td in soup.find_all('td',{'class':'agent-short-cell-right'}):
    agent_name = td.find('div').span.b.text.strip()
    agent_role = td.find('div').find_all('span')[1].text.replace(',','').strip()
    office_name = td.find_all('div')[1].text
    office_phone = td.find_all('div')[2].text
    fax = td.find_all('div')[3].text
    agent_url = 'https://www.homelife.ca'+td.find_all('div')[5].find('span').find('a')['href']
    df.loc[z,'agent_url'] = agent_url
    df.loc[z,'agent_name'] = agent_name
    df.loc[z,'agent_role'] = agent_role
    df.loc[z,'office_name'] = office_name
    df.loc[z,'office_phone'] = office_phone.replace('Office:','').strip()
    df.loc[z,'office_fax'] = fax.replace('Fax:','').strip()
    z = z+1

# %%
for td in soup.find_all('td',{'class':'agent-short-cell-right'}):
    agent_name = td.find('div').span.b.text.strip()
    agent_role = td.find('div').find_all('span')[1].text.replace(',','').strip()
    office_name = td.find_all('div')[1].text
    office_phone = td.find_all('div')[2].text
    fax = td.find_all('div')[3].text
    agent_url = 'https://www.homelife.ca'+td.find_all('div')[5].find('span').find('a')['href']
    df.loc[z,'agent_url'] = agent_url
    df.loc[z,'agent_name'] = agent_name
    df.loc[z,'agent_role'] = agent_role
    df.loc[z,'office_name'] = office_name
    df.loc[z,'office_phone'] = office_phone.replace('Office:','').strip()
    df.loc[z,'office_fax'] = fax.replace('Fax:','').strip()
    z = z+1

# %%
df.to_csv('Homerealty.csv',index=False)

# %%
df = pd.read_csv('Homerealty.csv')

# %%
address = 'Toronto, Ontario, Canada M6G 1C9'

# %%
state = 'ON'

# %%
Zip = 'M6G 1C9'

# %%
df3 = pd.DataFrame([],columns=['unique_id', 'agent_url', 'agent_dp', 'agent_name', 'agent_phone',
       'agent_email', 'agent_role', 'agent_license', 'agent_areaserved',
       'agent_designations', 'agent_facebook', 'agent_instagram',
       'agent_twitter', 'agent_linkedin', 'agent_pinterest', 'agent_youtube',
       'agent_site', 'agent_special_tag', 'agent_rating', 'office_address',
       'office_fax', 'office_branch', 'office_name', 'office_phone',
       'office_site', 'office_zip', 'office_state', 'other_phone',
       'company_facebook', 'company_linkedin', 'company_name', 'company_site',
       'company_twitter', 'date_of_data_extraction', 'data_extracted_by',
       'dataextraction_uuid'])

# %%
df
# Out:
#                                             agent_url  \
# 0                   https://www.homelife.ca/node/9469
# 1                 https://www.homelife.ca/node/548074
# 2                   https://www.homelife.ca/node/9454
# 3                 https://www.homelife.ca/node/627458
# 4                   https://www.homelife.ca/node/9456
# 5                 https://www.homelife.ca/node/490580
# 6                 https://www.homelife.ca/node/548068
# 7                   https://www.homelife.ca/node/9446
# 8                  https://www.homelife.ca/DON-ABELHA
# 9                   https://www.homelife.ca/node/9459
# 10  https://www.homelife.cahttp://www.cancel-rishi...
# 11          https://www.homelife.ca/Gregory-Silvaggio
# 12                  https://www.homelife.ca/node/9464
# 13                  https://www.homelife.ca/node/9449
# 14                https://www.homelife.ca/Happy-Pham-
# 15                https://www.homelife.ca/KHANH-TRINH
# ...

# %%
from datetime import datetime

# %%
for i in df.columns:
    df3[i] = df[i]

# %%
df3['agent_url'] = df['agent_url']

# %%
for i in range(len(df3)):
    
    df3.loc[i,'unique_id'] = 'Home_life_'+str(i+1)
    df3.loc[i,'date_of_data_extraction'] = datetime.now()
    df3.loc[i,'company_name'] = 'Home Life'
    df3.loc[i,'company_site'] = 'https://www.homelife.ca/'
    df3.loc[i,'date_of_data_extraction'] = datetime.now()
    df3.loc[i,'data_extracted_by'] = 'Tamil'
    df3.loc[i,'dataextraction_uuid'] = 'Tamil-'+datetime.now().strftime('%d-%m-%Y')
    df3.loc[i,'office_address'] = address
    df3.loc[i,'office_state'] = state
    df3.loc[i,'office_zip'] = Zip

# %%
df3 = df3.fillna('')

# %%
df4 = df3[['unique_id', 'agent_url', 'agent_dp', 'agent_name', 'agent_phone',
       'agent_email', 'agent_role', 'agent_license', 'agent_areaserved',
       'agent_designations', 'agent_facebook', 'agent_instagram',
       'agent_twitter', 'agent_linkedin', 'agent_pinterest', 'agent_youtube',
       'agent_site', 'agent_special_tag', 'agent_rating', 'office_address',
       'office_fax', 'office_branch', 'office_name', 'office_phone',
       'office_site', 'office_zip', 'office_state', 'other_phone',
       'company_facebook', 'company_linkedin', 'company_name', 'company_site',
       'company_twitter', 'date_of_data_extraction', 'data_extracted_by',
       'dataextraction_uuid']]

# %%
df4
# Out:
#        unique_id                                          agent_url agent_dp  \
# 0    Home_life_1                  https://www.homelife.ca/node/9469
# 1    Home_life_2                https://www.homelife.ca/node/548074
# 2    Home_life_3                  https://www.homelife.ca/node/9454
# 3    Home_life_4                https://www.homelife.ca/node/627458
# 4    Home_life_5                  https://www.homelife.ca/node/9456
# 5    Home_life_6                https://www.homelife.ca/node/490580
# 6    Home_life_7                https://www.homelife.ca/node/548068
# 7    Home_life_8                  https://www.homelife.ca/node/9446
# 8    Home_life_9                 https://www.homelife.ca/DON-ABELHA
# 9   Home_life_10                  https://www.homelife.ca/node/9459
# 10  Home_life_11  https://www.homelife.cahttp://www.cancel-rishi...
# 11  Home_life_12          https://www.homelife.ca/Gregory-Silvaggio
# 12  Home_life_13                  https://www.homelife.ca/node/9464
# ...

# %%
import psycopg2
import pandas as pd
import psycopg2.extras as extras

# %%
connection = psycopg2.connect(user='postgres',
                              password='smartsetter',
                              host='ss-db-data-dev.cpeist8s9qou.us-west-2.rds.amazonaws.com',
                              port=5432,
                              database='postgres')

# %%
cursor = connection.cursor()

# %%
def execute_values(conn, df, table):
    # Create a list of tupples from the dataframe values
    tuples = [tuple(x) for x in df.to_numpy()]
    # Comma-separated dataframe columns
    cols = ','.join(list(df.columns))
    # SQL quert to execute
    query  = "INSERT INTO %s(%s) VALUES %%s;" % (table, cols)
    cursor = conn.cursor()
    try:
        extras.execute_values(cursor, query, tuples)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("execute_values() done")
    cursor.close()

# %%
execute_values(connection,df4 , 'internal_data_exctraction')
# Out:
# execute_values() done
