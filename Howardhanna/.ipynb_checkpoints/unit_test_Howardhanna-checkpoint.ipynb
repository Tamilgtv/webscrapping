# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests as rq

# %%
page = rq.get('https://www.howardhanna.com/Office/AgentList?OfficeCode=00218&OrderBy=NameAsc&PageSize=94&Page=1')

# %%
page = rq.get('https://www.howardhanna.com/Agent/List?PageSize=100&Page=2')

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Howard Hanna Real Estate Services - Agent - Agentlist</title><meta content="Howard Hanna Real Estate Services ranks nationally as one of the four largest real estate companies with offices across PA, OH, NY, VA, MI, WV, NC &amp; MD" name="description"><meta content="Business: Real Estate" name="CLASSIFICATION"/><meta content="https://www.howardhanna.com" name="HOME_URL"/><meta content="Howard Hanna Real Estate" name="COPYRIGHT"/><meta content="Business: Real Estate" name="CATEGORY"/><meta content="Howard Hanna Real Estate" name="AUTHOR"/>
# ...

# %%
soup.find_all('a',{'class':'titleUnderlined'})
# Out:
# [<a class="titleUnderlined" href="/Agent/Detail/Colleen-Alexander/170595">Colleen Alexander</a>,
#  <a class="titleUnderlined" href="/Agent/Detail/Jeri-Alexander/b33c235c46134e60bb255a41b0f6d176">Jeri Alexander</a>,
#  <a class="titleUnderlined" href="/Agent/Detail/Kay-Michael-Alexander/32986">Kay Michael Alexander</a>,
#  <a class="titleUnderlined" href="/Agent/Detail/Kristy-Alexander/ab38beee49b04851a550247f3e23989a">Kristy Alexander</a>,
#  <a class="titleUnderlined" href="/Agent/Detail/Laura-Alexander/cd646728de7a4379a5632b0c7e7fca35">Laura Alexander</a>,
#  <a class="titleUnderlined" href="/Agent/Detail/Frank-Alfero/356b748a3a9a45d383fe9646271278ed">Frank Alfero</a>,
#  <a class="titleUnderlined" href="/Agent/Detail/Terry-Alfero/82f7051eaf574cf1bec1f59f0e905402">Terry Alfero</a>,
#  <a class="titleUnderlined" href="/Agent/Detail/Jane-Alfidi/843a1be6abab4f0fbf231a2b4f3febd4">Jane Alfidi</a>,
# ...

# %%
len(soup.find_all('a',{'class':'titleUnderlined'}))
# Out:
# 101

# %%
z = 0
df = pd.DataFrame([])
for link in soup.find_all('a',{'class':'titleUnderlined'}):
    df.loc[z,'link'] = 'https://www.howardhanna.com/'+link['href']
    z=z+1

# %%
df
# Out:
#                                                  link
# 0   https://www.howardhanna.com//Agent/Detail/Tame...
# 1   https://www.howardhanna.com//Agent/Detail/Rob-...
# 2   https://www.howardhanna.com//Agent/Detail/Jen-...
# 3   https://www.howardhanna.com//Agent/Detail/Bryc...
# 4   https://www.howardhanna.com//Agent/Detail/Sue-...
# ..                                                ...
# 89  https://www.howardhanna.com//Agent/Detail/Kevi...
# 90  https://www.howardhanna.com//Agent/Detail/Miri...
# 91  https://www.howardhanna.com//Agent/Detail/Sela...
# 92  https://www.howardhanna.com//Agent/Detail/Debb...
# 93  https://www.howardhanna.com//Agent/Detail/Kary...
#
# [94 rows x 1 columns]

# %%
z = 0
df = pd.DataFrame([])
for page_no in range(1,103):
    page = rq.get('https://www.howardhanna.com/Agent/List?PageSize=100&Page=2')
    for link in soup.find_all('a',{'class':'titleUnderlined'}):

# %%
for link in soup.find_all('a',{'class':'titleUnderlined'}):
    df.loc[z,'link'] = 'https://www.howardhanna.com/'+link['href']
    z=z+1

# %%
df.to_csv('howardhana_link.csv',index=False)
