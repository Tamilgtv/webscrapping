# %%
import pandas as pd
pd.set_option('display.max_columns', 65)

# %%
import os
import glob
#directory
path = os.getcwd() 

#getting All csv file names from the directory
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
csv_files
# Out:
# ['D:\\Tamil\\AIMLEAP\\CBN\\CBN_BOT\\kw\\kw_35k_38k\\output\\kw_data-no_emailSelenium_35k_36k.csv',
#  'D:\\Tamil\\AIMLEAP\\CBN\\CBN_BOT\\kw\\kw_35k_38k\\output\\kw_data-no_emailSelenium_36k_37k.csv',
#  'D:\\Tamil\\AIMLEAP\\CBN\\CBN_BOT\\kw\\kw_35k_38k\\output\\kw_data-no_emailSelenium_37k_38k.csv']

# %%
overall_op = pd.read_csv(csv_files[0])
for i in range(len(csv_files)):
    if i != 0:
        a = pd.read_csv(csv_files[i])
        overall_op = pd.concat([overall_op,a])

# %%
overall_op.to_csv('kw_data-no_emailSelenium_35k_38k.csv')

# %%
overall_op
# Out:
#      Unnamed: 0                                       agent_url  \
# 0             0  https://kw.com/agent/UPA-6587385419101425665-0
# 1             0  https://kw.com/agent/UPA-6587385362547232774-8
# 2             0  https://kw.com/agent/UPA-6587385361250553857-7
# 3             0  https://kw.com/agent/UPA-6587384998941011969-7
# 4             0  https://kw.com/agent/UPA-6587385174341025794-3
# ..          ...                                             ...
# 995           0  https://kw.com/agent/UPA-6587385320814129157-0
# 996           0  https://kw.com/agent/UPA-6587385407997710339-8
# 997           0  https://kw.com/agent/UPA-6587385162228289539-6
# 998           0  https://kw.com/agent/UPA-6682305710377422848-4
# 999           0  https://kw.com/agent/UPA-6587385372733018114-5
#
#                  agent_name                                       agent_role  \
# 0                       NaN                                              NaN
# 1             Daniel Kelten         Real Estate Agent at Kelten Realty Group
# 2           Daniel Kendrick                                              NaN
# 3             Daniel Klucas  Real Estate Agent at Daniel J. Klucas - Realtor
# 4             DANIEL KLUGER                                              NaN
# ..                      ...                                              ...
# 995           Robin DiMarco                                              NaN
# 996           Darren DiMare                                              NaN
# 997          Marissa DiMare            Real Estate Agent at The DiMare Group
# 998  Candace DiMarsico-Wong                                              NaN
# 999       Johanna DiMartino                                              NaN
#
#                location agent_dp           tag                  agent_email  \
# 0                   NaN      NaN           NaN                          NaN
# 1          Portland, OR      NaN           NaN               dkelten@kw.com
# 2          Franklin, TN      NaN           NaN  daniel@buildupnashville.com
# 3    Peachtree City, GA      NaN           NaN        danielj.klucas@kw.com
# 4         Blue Bell, PA      NaN           NaN    DanielCKluger@comcast.net
# ..                  ...      ...           ...                          ...
# 995      Moorestown, NJ      NaN           NaN         robin.dimarco@kw.com
# 996                 NaN      NaN           NaN  dimaredevelopment@gmail.com
# 997      Lavallette, NJ      NaN  luxury agent   marissa@thedimaregroup.com
# 998                 NaN      NaN           NaN          cdw10@optonline.net
# 999   Coral Springs, FL      NaN           NaN     johanna.dimartino@kw.com
#
#       mobile_number   office_number  \
# 0               NaN             NaN
# 1    (503) 209-3088  (503) 548-4848
# 2    (615) 300-5925  (615) 300-5925
# 3    (678) 826-9714  (770) 632-1112
# 4    (215) 280-5584  (215) 654-6071
# ..              ...             ...
# 995  (856) 981-5878  (856) 316-1100
# 996  (732) 239-9538  (732) 250-3627
# 997  (908) 770-6146  (239) 919-4447
# 998  (973) 476-2025  (973) 539-1120
# 999  (954) 263-3895  (954) 688-5400
#
#                                       agent_license  \
# 0                                               NaN
# 1                    Agent License # 201223497 (OR)
# 2                       Agent License # 342631 (TN)
# 3                       Agent License # 385633 (GA)
# 4                     Agent License # RS309031 (PA)
# ..                                              ...
# 995                    Agent License # 1647135 (NJ)
# 996                    Agent License # 1111111 (NJ)
# 997  Agent License # 0679604 (NJ), # BK3306927 (FL)
# 998                    Agent License # 8939722 (NJ)
# 999                    Agent License # 3400698 (FL)
#
#                                              agent_bio  \
# 0                                                  NaN
# 1    "Work hard and be nice to everybody." \nI keep...
# 2    Spent 7 years in Business Operations & Managem...
# 3    Why Choose Me As Your Agent? When you work wit...
# 4                                       ABR,e-PRO,SRES
# ..                                                 ...
# 995  Robin is the epitome of integrity, energy, and...
# 996  Darren DiMare, co-founder of The DiMare Group,...
# 997  With over 14 years of real estate experience, ...
# 998                                                NaN
# 999  Why Choose Me As Your Agent?\n\nWhen you work ...
#
#                                           serviceAreas  \
# 0                                                  NaN
# 1    Beaverton, Cedar Hills, Gresham, Hillsboro, La...
# 2    Arrington, Bellevue, Brentwood, Columbia, Fran...
# 3    Brooks, Coweta County, Fayette County, Fayette...
# 4    Ambler, Blue Bell, Collegeville, Conshohocken,...
# ..                                                 ...
# 995  Cherry Hill, Cinnaminson, Haddonfield, Hainesp...
# 996  Barnegat Light Borough, Barnegat Township, Bay...
# 997  Allenhurst, Aqualane Shores, Asbury Park, Avon...
# 998  Basking Ridge, Bedminster, Boonton, Butler, Ch...
# 999  Broward, Coral Springs, Fort Lauderdale, Holly...
#
#                     office_name  \
# 0                           NaN
# 1           Kelten Realty Group
# 2                           NaN
# 3    Daniel J. Klucas - Realtor
# 4                           NaN
# ..                          ...
# 995                         NaN
# 996                         NaN
# 997            The DiMare Group
# 998                         NaN
# 999                         NaN
#
#                                         office_address logo_url  \
# 0                                                  NaN      NaN
# 1    919 NE 19th Ave, Suite 100, Portland, OR 97232...      NaN
# 2                                                  NaN      NaN
# 3    1200 Commerce Dr., Suite 110, https://danielj-...      NaN
# 4                                                  NaN      NaN
# ..                                                 ...      ...
# 995                                                NaN      NaN
# 996                                                NaN      NaN
# 997  1400 Grand Central Ave, Lavallette, NJ 08735 |...      NaN
# 998                                                NaN      NaN
# 999                                                NaN      NaN
#
#                                        facebook  \
# 0                                           NaN
# 1    https://www.facebook.com/dkeltenpnwrealtor
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 995                                         NaN
# 996                                         NaN
# 997    https://www.facebook.com/TheDiMareGroup/
# 998                                         NaN
# 999                                         NaN
#
#                                              instagram  \
# 0                                                  NaN
# 1         https://www.instagram.com/dkeltenpnwrealtor/
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997  https://www.instagram.com/marissa_thedimaregroup/
# 998                                                NaN
# 999                                                NaN
#
#                          twitter                                     linkedin  \
# 0                            NaN                                          NaN
# 1    https://twitter.com/DKelten         https://www.linkedin.com/in/dkelten/
# 2                            NaN                                          NaN
# 3                            NaN                                          NaN
# 4                            NaN                                          NaN
# ..                           ...                                          ...
# 995                          NaN                                          NaN
# 996                          NaN                                          NaN
# 997                          NaN  https://www.linkedin.com/in/marissa-dimare/
# 998                          NaN                                          NaN
# 999                          NaN                                          NaN
#
#                                           Market_Cente  \
# 0                                                  NaN
# 1                                     Portland Central
# 2                                                  NaN
# 3                             Atlanta - Peachtree City
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997  Keller Williams Shore Properties/Keller Willia...
# 998                                                NaN
# 999                                                NaN
#
#                  agent_language Specialties_Designations  \
# 0                           NaN                      NaN
# 1    English, Japanese, Spanish                      NaN
# 2                       English                  Realtor
# 3                       English                Realtor��
# 4                       English         ABR, e-PRO, SRES
# ..                          ...                      ...
# 995                     English        Real Estate Agent
# 996                     English                      NaN
# 997                     English                   Luxury
# 998                     English                      NaN
# 999            English, Spanish                REALTOR��
#
#                                 social_media_links_str  \
# 0                                                  NaN
# 1    https://www.facebook.com/dkeltenpnwrealtor|htt...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997  https://www.facebook.com/TheDiMareGroup/|https...
# 998                                                NaN
# 999                                                NaN
#
#                       agent_website
# 0                               NaN
# 1            https://dkelten.kw.com
# 2                               NaN
# 3    https://danielj-klucas.kw.com/
# 4                               NaN
# ..                              ...
# 995                             NaN
# 996                             NaN
# 997  https://www.thedimaregroup.com
# 998                             NaN
# 999                             NaN
#
# [3001 rows x 25 columns]
